# %% [markdown]
# # Capstone Project Introduction and Data

# %% [markdown]
# This notebook contains an introduction to the Capstone Data Science project that I have devised, the business problem it intends to address, and a summary of the data that I will use to complete the project.

# %% [markdown]
# ### Business Problem

# %% [markdown]
# I am a keen outdoor enthusiast as are many others, and one of my favourite hobbies is hiking. Whenever I am on holiday I will try to find local hikes which combine the right level of challenge and natural beauty, but doing so based on random internet searches or individual recommendations often makes me wonder if I have made the most of the area I am visiting, or indeed whether I have visited the best area to persue my hobby.

# %% [markdown]
# The problem this project will address is the challenge of selecting an appropriate location for a hiking holiday (and by appropriate I am talking about locations that have access to the right number of hikes, that are of the right quality and difficulty).

# %% [markdown]
# ![alt text](https://www.backpacker.com/.image/c_limit%2Ccs_srgb%2Cq_auto:good%2Cw_860/MTQ5NTkxODMyNDA4MzY4NjA0/35541767156_8ba52234a0_o.webp "Logo Title Text 1")

# %% [markdown]
# ### Data

# %% [markdown]
# There are two main data sources I will use for this project:
# + **Hiking Project:** This is a website that offers a free-to-use API that will allow me to retrieve data relating to different hiking routes. I have given an example below. The web address is: https://www.hikingproject.com/data
# + **USA counties:** I will use the counties of the USA as potential 'holidaying locations' for this project. Data relating to these is available, with latitude and longitude co-oridnates at: https://en.wikipedia.org/w/index.php?title=User:Michael_J/County_table&oldid=368803236

# %% [markdown]
# ### Data retrieval example (hikingproject.com)

# %% [markdown]
# The following code sections demonstrate how data relating to hiking trails can be retrieved from Hiking Project.

# %% [markdown]
# 1. First import libraries:

# %%
import requests
import pandas as pd

# %% [markdown]
# 2. Define API parameters and create url for API request:

# %%
lat = 40.0274 # Random US location to test
long = -105.2519 # Random US location to test
maxDistance = 15 # Max distance from defined locations
maxResults = 500 # Max number of results is 500 from this API
key = '200581789-f40ea73ef2b0bac87cf5c431217fc969' # My Hiking Project API key

# create the API request URL
url = 'https://www.hikingproject.com/data/get-trails?lat={}&lon={}&maxDistance={}&maxResults={}&key={}'.format(
    lat, 
    long,
    maxDistance,
    maxResults,
    key)

# %% [markdown]
# 3. Make API call:

# %%
results = requests.get(url).json()["trails"]

# %% [markdown]
# 4. Check results:

# %%
results
# Out:
# [{'id': 7000130,
#   'name': 'Bear Peak Out and Back',
#   'type': 'Featured Hike',
#   'summary': 'A must-do hike for Boulder locals and visitors alike!',
#   'difficulty': 'blueBlack',
#   'stars': 4.6,
#   'starVotes': 108,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7000130/bear-peak-out-and-back',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7061992_sqsmall_1566068327.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7061992_small_1566068327.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7061992_smallMed_1566068327.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7061992_medium_1566068327.jpg',
#   'length': 5.7,
#   'ascent': 2541,
#   'descent': -2540,
#   'high': 8342,
#   'low': 6103,
#   'longitude': -105.2755,
#   'latitude': 39.9787,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-08-10 16:37:58'},
#  {'id': 7004226,
#   'name': "Sunshine Lion's Lair Loop",
#   'type': 'Featured Hike',
#   'summary': 'Great Mount Sanitas views are the reward for this gentler loop in Sunshine Canyon.',
#   'difficulty': 'blue',
#   'stars': 4.5,
#   'starVotes': 103,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7004226/sunshine-lions-lair-loop',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7039883_sqsmall_1555092747.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7039883_small_1555092747.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7039883_smallMed_1555092747.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7039883_medium_1555092747.jpg',
#   'length': 5.3,
#   'ascent': 1261,
#   'descent': -1282,
#   'high': 6800,
#   'low': 5530,
#   'longitude': -105.2979,
#   'latitude': 40.02,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry - Careful of ticks in the high grass along Sunshine right now!',
#   'conditionDate': '2019-07-10 14:09:36'},
#  {'id': 7011192,
#   'name': 'Boulder Skyline Traverse',
#   'type': 'Featured Hike',
#   'summary': 'The classic long mountain route in Boulder.',
#   'difficulty': 'black',
#   'stars': 4.7,
#   'starVotes': 70,
#   'location': 'Superior, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7011192/boulder-skyline-traverse',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7048859_sqsmall_1555540136.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7048859_small_1555540136.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7048859_smallMed_1555540136.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7048859_medium_1555540136.jpg',
#   'length': 16.3,
#   'ascent': 5409,
#   'descent': -5492,
#   'high': 8492,
#   'low': 5417,
#   'longitude': -105.2582,
#   'latitude': 39.9388,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry',
#   'conditionDate': '2019-07-30 17:52:30'},
#  {'id': 7004682,
#   'name': 'Royal Arch Out and Back',
#   'type': 'Featured Hike',
#   'summary': 'A classic Boulder hike to a natural arch with great views.',
#   'difficulty': 'blueBlack',
#   'stars': 4.4,
#   'starVotes': 145,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7004682/royal-arch-out-and-back',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7002679_sqsmall_1554226731.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7002679_small_1554226731.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7002679_smallMed_1554226731.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7002679_medium_1554226731.jpg',
#   'length': 3.3,
#   'ascent': 1311,
#   'descent': -1312,
#   'high': 6917,
#   'low': 5691,
#   'longitude': -105.283,
#   'latitude': 39.9997,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-07-21 14:20:07'},
#  {'id': 7002439,
#   'name': 'Walker Ranch',
#   'type': 'Featured Hike',
#   'summary': 'An awesome and challenging hike near Boulder with great scenery.',
#   'difficulty': 'blueBlack',
#   'stars': 4.5,
#   'starVotes': 118,
#   'location': 'Coal Creek, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7002439/walker-ranch',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7039625_sqsmall_1555092312.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7039625_small_1555092312.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7039625_smallMed_1555092312.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7039625_medium_1555092312.jpg',
#   'length': 7.6,
#   'ascent': 1594,
#   'descent': -1585,
#   'high': 7335,
#   'low': 6439,
#   'longitude': -105.3378,
#   'latitude': 39.9511,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry',
#   'conditionDate': '2019-08-11 12:20:56'},
#  {'id': 7011191,
#   'name': 'Green Mountain via Ranger/Saddle Rock Loop',
#   'type': 'Featured Hike',
#   'summary': 'A loop with a variety of terrain, a lot of climbing, and great views of Boulder.',
#   'difficulty': 'blueBlack',
#   'stars': 4.5,
#   'starVotes': 76,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7011191/green-mountain-via-rangersaddle-rock-loop',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7003740_sqsmall_1554235436.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7003740_small_1554235436.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003740_smallMed_1554235436.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7003740_medium_1554235436.jpg',
#   'length': 4.9,
#   'ascent': 2305,
#   'descent': -2277,
#   'high': 8099,
#   'low': 5806,
#   'longitude': -105.2928,
#   'latitude': 39.9975,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry',
#   'conditionDate': '2019-08-03 18:22:28'},
#  {'id': 7000000,
#   'name': 'Mount Sanitas Loop',
#   'type': 'Featured Hike',
#   'summary': 'Very popular and scenic loop right from the edge of town.',
#   'difficulty': 'blueBlack',
#   'stars': 4.1,
#   'starVotes': 102,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7000000/mount-sanitas-loop',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7039883_sqsmall_1555092747.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7039883_small_1555092747.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7039883_smallMed_1555092747.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7039883_medium_1555092747.jpg',
#   'length': 3.2,
#   'ascent': 1281,
#   'descent': -1280,
#   'high': 6780,
#   'low': 5521,
#   'longitude': -105.2977,
#   'latitude': 40.0202,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry',
#   'conditionDate': '2019-08-27 15:10:20'},
#  {'id': 7001019,
#   'name': 'Betasso Preserve',
#   'type': 'Featured Hike',
#   'summary': 'This hike is easily accessible from Boulder and offers amazing singletrack with beautiful views.',
#   'difficulty': 'blue',
#   'stars': 4.2,
#   'starVotes': 58,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7001019/betasso-preserve',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7029200_sqsmall_1554920151.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7029200_small_1554920151.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7029200_smallMed_1554920151.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7029200_medium_1554920151.jpg',
#   'length': 6.7,
#   'ascent': 776,
#   'descent': -778,
#   'high': 6575,
#   'low': 6178,
#   'longitude': -105.3446,
#   'latitude': 40.0164,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-06-24 10:31:06'},
#  {'id': 7009076,
#   'name': 'Mountain Lion Trail',
#   'type': 'Featured Hike',
#   'summary': 'Colorado wrapped into one trail offering elevation, lakes, creeks, and mountain views.',
#   'difficulty': 'blue',
#   'stars': 4.5,
#   'starVotes': 50,
#   'location': 'Coal Creek, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7009076/mountain-lion-trail',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7044196_sqsmall_1555109790.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7044196_small_1555109790.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7044196_smallMed_1555109790.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7044196_medium_1555109790.jpg',
#   'length': 6.9,
#   'ascent': 1531,
#   'descent': -1509,
#   'high': 8901,
#   'low': 7627,
#   'longitude': -105.3606,
#   'latitude': 39.8505,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Mostly Dry',
#   'conditionDate': '2019-06-23 13:47:51'},
#  {'id': 7017973,
#   'name': 'Golden Gate Canyon State Park Loop',
#   'type': 'Featured Hike',
#   'summary': 'High altitude trail hiking with steeper terrain and scenic mountain views.',
#   'difficulty': 'blueBlack',
#   'stars': 4.4,
#   'starVotes': 24,
#   'location': 'Coal Creek, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7017973/golden-gate-canyon-state-park-loop',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7051822_sqsmall_1555693701.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7051822_small_1555693701.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7051822_smallMed_1555693701.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7051822_medium_1555693701.jpg',
#   'length': 13.2,
#   'ascent': 2232,
#   'descent': -2230,
#   'high': 9493,
#   'low': 8228,
#   'longitude': -105.4084,
#   'latitude': 39.833,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry',
#   'conditionDate': '2019-08-10 13:56:16'},
#  {'id': 7017569,
#   'name': 'Marshall Mesa to Spring Brook Loop',
#   'type': 'Featured Hike',
#   'summary': 'Some of the best trails that Boulder has to offer with a variety of options that never get old.',
#   'difficulty': 'blue',
#   'stars': 4.4,
#   'starVotes': 25,
#   'location': 'Superior, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7017569/marshall-mesa-to-spring-brook-loop',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7002458_sqsmall_1554226116.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7002458_small_1554226116.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7002458_smallMed_1554226116.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7002458_medium_1554226116.jpg',
#   'length': 11.1,
#   'ascent': 893,
#   'descent': -893,
#   'high': 6236,
#   'low': 5567,
#   'longitude': -105.2313,
#   'latitude': 39.9527,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry',
#   'conditionDate': '2019-06-30 15:13:30'},
#  {'id': 7004678,
#   'name': 'Welcome to Chautauqua',
#   'type': 'Featured Hike',
#   'summary': 'Perhaps the most popular (crowded!) hike in America. And for good reason.',
#   'difficulty': 'greenBlue',
#   'stars': 4.3,
#   'starVotes': 20,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7004678/welcome-to-chautauqua',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7003311_sqsmall_1554233834.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7003311_small_1554233834.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003311_smallMed_1554233834.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7003311_medium_1554233834.jpg',
#   'length': 1.3,
#   'ascent': 436,
#   'descent': -434,
#   'high': 6139,
#   'low': 5703,
#   'longitude': -105.2829,
#   'latitude': 39.9988,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7005887,
#   'name': 'Sugarloaf Mountain',
#   'type': 'Featured Hike',
#   'summary': 'The best bang-for-your-buck view trail in Boulder County.',
#   'difficulty': 'greenBlue',
#   'stars': 4.3,
#   'starVotes': 18,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7005887/sugarloaf-mountain',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7031490_sqsmall_1554931128.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7031490_small_1554931128.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7031490_smallMed_1554931128.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7031490_medium_1554931128.jpg',
#   'length': 1.4,
#   'ascent': 432,
#   'descent': -432,
#   'high': 8892,
#   'low': 8460,
#   'longitude': -105.4251,
#   'latitude': 40.0255,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry',
#   'conditionDate': '2019-09-01 23:47:19'},
#  {'id': 7004555,
#   'name': 'Flagstaff Summit Loop',
#   'type': 'Featured Hike',
#   'summary': 'Experience awesome views and dense douglas-fir forest on this easy hike.',
#   'difficulty': 'greenBlue',
#   'stars': 4.3,
#   'starVotes': 16,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7004555/flagstaff-summit-loop',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7003658_sqsmall_1554234777.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7003658_small_1554234777.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003658_smallMed_1554234777.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7003658_medium_1554234777.jpg',
#   'length': 2.4,
#   'ascent': 346,
#   'descent': -337,
#   'high': 6919,
#   'low': 6758,
#   'longitude': -105.3032,
#   'latitude': 40.0041,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry',
#   'conditionDate': '2019-06-29 18:02:45'},
#  {'id': 7010666,
#   'name': 'East Mag Tour',
#   'type': 'Featured Hike',
#   'summary': 'Loop through the East Magnolia area trails on mostly buff singletrack.',
#   'difficulty': 'blue',
#   'stars': 3.8,
#   'starVotes': 20,
#   'location': 'Nederland, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7010666/east-mag-tour',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7035339_sqsmall_1555019839.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7035339_small_1555019839.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7035339_smallMed_1555019839.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7035339_medium_1555019839.jpg',
#   'length': 7.5,
#   'ascent': 1005,
#   'descent': -1014,
#   'high': 8704,
#   'low': 8384,
#   'longitude': -105.4752,
#   'latitude': 39.9535,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Nice hike for wildflowers. Good elevation changes. Popular for trail running & biking it seems. Not crowded.',
#   'conditionDate': '2019-07-10 21:22:16'},
#  {'id': 7053374,
#   'name': 'Indian Peaks Traverse (IPT)',
#   'type': 'Featured Hike',
#   'summary': 'An epic, long distance trail connecting Boulder to Winter Park, and one that is in the process of substantial upgrades!',
#   'difficulty': 'blueBlack',
#   'stars': 4.5,
#   'starVotes': 2,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7053374/indian-peaks-traverse-ipt',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7017003_sqsmall_1554828628.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7017003_small_1554828628.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7017003_smallMed_1554828628.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7017003_medium_1554828628.jpg',
#   'length': 71.2,
#   'ascent': 9173,
#   'descent': -5813,
#   'high': 11665,
#   'low': 5425,
#   'longitude': -105.2946,
#   'latitude': 40.0137,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry: Perfect',
#   'conditionDate': '2019-08-11 17:42:24'},
#  {'id': 7041440,
#   'name': 'Dirty Bismark',
#   'type': 'Featured Hike',
#   'summary': 'A rare, long, flat-ish loop on dirt in the Front Range, named after the Morgul Bismarck road cycling route.',
#   'difficulty': 'greenBlue',
#   'stars': 3.9,
#   'starVotes': 15,
#   'location': 'Superior, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7041440/dirty-bismark',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7030529_sqsmall_1554927164.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7030529_small_1554927164.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7030529_smallMed_1554927164.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7030529_medium_1554927164.jpg',
#   'length': 15.7,
#   'ascent': 970,
#   'descent': -970,
#   'high': 5960,
#   'low': 5522,
#   'longitude': -105.231,
#   'latitude': 39.9527,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry',
#   'conditionDate': '2019-07-25 08:48:40'},
#  {'id': 7004681,
#   'name': 'South Mesa Loop',
#   'type': 'Featured Hike',
#   'summary': 'Stunning scenery and a little history...',
#   'difficulty': 'greenBlue',
#   'stars': 3.9,
#   'starVotes': 14,
#   'location': 'Superior, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7004681/south-mesa-loop',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7003963_sqsmall_1554236063.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7003963_small_1554236063.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003963_smallMed_1554236063.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7003963_medium_1554236063.jpg',
#   'length': 3.1,
#   'ascent': 508,
#   'descent': -507,
#   'high': 6123,
#   'low': 5623,
#   'longitude': -105.2582,
#   'latitude': 39.9388,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry',
#   'conditionDate': '2019-07-04 15:09:14'},
#  {'id': 7004512,
#   'name': 'Boulder Valley Ranch Loop',
#   'type': 'Featured Hike',
#   'summary': 'This scenic loop through rolling farmland is a highlight of the Boulder Valley Ranch area.',
#   'difficulty': 'green',
#   'stars': 4.1,
#   'starVotes': 7,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7004512/boulder-valley-ranch-loop',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7003610_sqsmall_1554234659.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7003610_small_1554234659.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003610_smallMed_1554234659.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7003610_medium_1554234659.jpg',
#   'length': 2.9,
#   'ascent': 170,
#   'descent': -166,
#   'high': 5348,
#   'low': 5208,
#   'longitude': -105.2627,
#   'latitude': 40.08,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-07-23 14:25:24'},
#  {'id': 7004042,
#   'name': 'Heil - Picture Rock Combo',
#   'type': 'Featured Hike',
#   'summary': 'Good singletrack, rocky paths, gradual incline that tops out to amazing views of the valley.',
#   'difficulty': 'blue',
#   'stars': 4.1,
#   'starVotes': 7,
#   'location': 'Lyons, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7004042/heil-picture-rock-combo',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7007799_sqsmall_1554323606.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7007799_small_1554323606.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7007799_smallMed_1554323606.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7007799_medium_1554323606.jpg',
#   'length': 20,
#   'ascent': 2241,
#   'descent': -2241,
#   'high': 6798,
#   'low': 5406,
#   'longitude': -105.3002,
#   'latitude': 40.1494,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry',
#   'conditionDate': '2019-06-19 22:42:05'},
#  {'id': 7000078,
#   'name': 'Shanahan Ridge',
#   'type': 'Featured Hike',
#   'summary': 'A straightforward hike on some of the best trail Boulder has to offer.',
#   'difficulty': 'blue',
#   'stars': 3.5,
#   'starVotes': 16,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7000078/shanahan-ridge',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7000468_sqsmall_1554159367.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7000468_small_1554159367.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7000468_smallMed_1554159367.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7000468_medium_1554159367.jpg',
#   'length': 3.9,
#   'ascent': 831,
#   'descent': -831,
#   'high': 6504,
#   'low': 5672,
#   'longitude': -105.2668,
#   'latitude': 39.9746,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-06-15 13:36:07'},
#  {'id': 7005429,
#   'name': 'Hogback Ridge Loop',
#   'type': 'Featured Hike',
#   'summary': 'This pleasant loop offers views, wildflowers and solitude - all conveniently close to town.',
#   'difficulty': 'greenBlue',
#   'stars': 3.4,
#   'starVotes': 19,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7005429/hogback-ridge-loop',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7004692_sqsmall_1554310573.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7004692_small_1554310573.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7004692_smallMed_1554310573.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7004692_medium_1554310573.jpg',
#   'length': 2.1,
#   'ascent': 740,
#   'descent': -739,
#   'high': 6400,
#   'low': 5660,
#   'longitude': -105.2898,
#   'latitude': 40.0688,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-07-23 14:25:01'},
#  {'id': 7006781,
#   'name': 'Dakota Ridge to Sanitas Valley Loop',
#   'type': 'Featured Hike',
#   'summary': 'A technical ascent with a great view of Boulder, followed by a nice, open downhill pitch.',
#   'difficulty': 'greenBlue',
#   'stars': 4,
#   'starVotes': 6,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7006781/dakota-ridge-to-sanitas-valley-loop',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7000176_sqsmall_1554158942.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7000176_small_1554158942.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7000176_smallMed_1554158942.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7000176_medium_1554158942.jpg',
#   'length': 2.3,
#   'ascent': 458,
#   'descent': -458,
#   'high': 5961,
#   'low': 5503,
#   'longitude': -105.2942,
#   'latitude': 40.0207,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7004519,
#   'name': 'Mesa Reservoir Loop',
#   'type': 'Featured Hike',
#   'summary': 'A satisfying trail, loops an unexpected patch of wetland oasis hidden among otherwise dry farmland.',
#   'difficulty': 'green',
#   'stars': 4,
#   'starVotes': 3,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7004519/mesa-reservoir-loop',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7003616_sqsmall_1554234677.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7003616_small_1554234677.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003616_smallMed_1554234677.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7003616_medium_1554234677.jpg',
#   'length': 1.9,
#   'ascent': 77,
#   'descent': -79,
#   'high': 5561,
#   'low': 5487,
#   'longitude': -105.2775,
#   'latitude': 40.0764,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-07-23 14:25:24'},
#  {'id': 7083705,
#   'name': 'Green-Bear Combo from Chautauqua',
#   'type': 'Featured Hike',
#   'summary': "A fun link-up of two of Boulder's most popular mountains.",
#   'difficulty': 'black',
#   'stars': 4,
#   'starVotes': 1,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7083705/green-bear-combo-from-chautauqua',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7003311_sqsmall_1554233834.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7003311_small_1554233834.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003311_smallMed_1554233834.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7003311_medium_1554233834.jpg',
#   'length': 13.5,
#   'ascent': 4512,
#   'descent': -4512,
#   'high': 8410,
#   'low': 5688,
#   'longitude': -105.283,
#   'latitude': 39.9997,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7076853,
#   'name': 'Marshall Mesa Valley Loop',
#   'type': 'Featured Hike',
#   'summary': 'An easygoing, view-laden, and relaxing loop through a calm valley full of foliage and wildlife.',
#   'difficulty': 'greenBlue',
#   'stars': 4,
#   'starVotes': 1,
#   'location': 'Superior, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7076853/marshall-mesa-valley-loop',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7058511_sqsmall_1557415158.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7058511_small_1557415158.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7058511_smallMed_1557415158.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7058511_medium_1557415158.jpg',
#   'length': 2.8,
#   'ascent': 187,
#   'descent': -186,
#   'high': 5716,
#   'low': 5532,
#   'longitude': -105.2313,
#   'latitude': 39.9528,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry',
#   'conditionDate': '2019-08-25 10:00:32'},
#  {'id': 7030731,
#   'name': 'Fourmile Creek - Gold Hill Connection',
#   'type': 'Featured Hike',
#   'summary': 'A solid hike with a good mix of open space and tree cover, single and doubletrack trail, and a couple of scenic views.',
#   'difficulty': 'greenBlue',
#   'stars': 3.8,
#   'starVotes': 4,
#   'location': 'Nederland, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7030731/fourmile-creek-gold-hill-connection',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7031798_sqsmall_1554931792.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7031798_small_1554931792.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7031798_smallMed_1554931792.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7031798_medium_1554931792.jpg',
#   'length': 4.9,
#   'ascent': 781,
#   'descent': -782,
#   'high': 9126,
#   'low': 8715,
#   'longitude': -105.5234,
#   'latitude': 40.0412,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7084200,
#   'name': 'Spring Brook / Goshawk Double Loop',
#   'type': 'Featured Hike',
#   'summary': 'A double-lollipop through prairie and lodgepole forest. Mostly hike-able with tough climbs and flowing descents.',
#   'difficulty': 'blue',
#   'stars': 3.5,
#   'starVotes': 2,
#   'location': 'Superior, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7084200/spring-brook-goshawk-double-loop',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7011129_sqsmall_1554399998.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7011129_small_1554399998.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7011129_smallMed_1554399998.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7011129_medium_1554399998.jpg',
#   'length': 8.3,
#   'ascent': 1065,
#   'descent': -1065,
#   'high': 6547,
#   'low': 5662,
#   'longitude': -105.2566,
#   'latitude': 39.9381,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-08-26 20:52:53'},
#  {'id': 7001540,
#   'name': 'Teller Farm - The Tank',
#   'type': 'Featured Hike',
#   'summary': 'Proverbially "Run with the Buffaloes" on this Boulder County and CU classic.',
#   'difficulty': 'green',
#   'stars': 3,
#   'starVotes': 4,
#   'location': 'Gunbarrel, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7001540/teller-farm-the-tank',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7000894_sqsmall_1554159816.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7000894_small_1554159816.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7000894_smallMed_1554159816.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7000894_medium_1554159816.jpg',
#   'length': 11,
#   'ascent': 517,
#   'descent': -517,
#   'high': 5381,
#   'low': 5070,
#   'longitude': -105.1586,
#   'latitude': 40.0218,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7009680,
#   'name': 'Coyote Run - Harper Lake - Davidson Mesa - Louisville Res',
#   'type': 'Featured Hike',
#   'summary': 'Hike an easy climb through Coyote Open Space to Harper Lake, with views of mountains at Davidson Mesa',
#   'difficulty': 'green',
#   'stars': 2.8,
#   'starVotes': 4,
#   'location': 'Louisville, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7009680/coyote-run-harper-lake-davidson-mesa-louisville-res',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7046019_sqsmall_1555533780.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7046019_small_1555533780.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7046019_smallMed_1555533780.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7046019_medium_1555533780.jpg',
#   'length': 8.3,
#   'ascent': 334,
#   'descent': -330,
#   'high': 5670,
#   'low': 5428,
#   'longitude': -105.1468,
#   'latitude': 39.9819,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7003752,
#   'name': 'First-Second Flatiron Trail',
#   'type': 'Trail',
#   'summary': 'A steep access trail used by climbers as a way down following an ascent of either the 1st or 2nd.',
#   'difficulty': 'blueBlack',
#   'stars': 4.4,
#   'starVotes': 45,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7003752/first-second-flatiron-trail',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7037961_sqsmall_1555087162.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7037961_small_1555087162.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7037961_smallMed_1555087162.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7037961_medium_1555087162.jpg',
#   'length': 0.6,
#   'ascent': 930,
#   'descent': 0,
#   'high': 7190,
#   'low': 6259,
#   'longitude': -105.2894,
#   'latitude': 39.9918,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry, Mostly Dry',
#   'conditionDate': '2019-08-03 16:12:05'},
#  {'id': 7004848,
#   'name': 'Rattlesnake Gulch Trail',
#   'type': 'Trail',
#   'summary': 'A lollipop loop in Eldorado State Park.',
#   'difficulty': 'blue',
#   'stars': 4.3,
#   'starVotes': 47,
#   'location': 'Coal Creek, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7004848/rattlesnake-gulch-trail',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7015412_sqsmall_1554826311.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7015412_small_1554826311.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7015412_smallMed_1554826311.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7015412_medium_1554826311.jpg',
#   'length': 2.3,
#   'ascent': 934,
#   'descent': -329,
#   'high': 7046,
#   'low': 6111,
#   'longitude': -105.288,
#   'latitude': 39.9294,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7000068,
#   'name': 'Mesa Trail',
#   'type': 'Trail',
#   'summary': 'A backbone of the south Boulder trail system that hugs the foothills.',
#   'difficulty': 'blue',
#   'stars': 4.5,
#   'starVotes': 28,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7000068/mesa-trail',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7002679_sqsmall_1554226731.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7002679_small_1554226731.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7002679_smallMed_1554226731.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7002679_medium_1554226731.jpg',
#   'length': 6.3,
#   'ascent': 801,
#   'descent': -1190,
#   'high': 6428,
#   'low': 5623,
#   'longitude': -105.2854,
#   'latitude': 39.9917,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-08-10 16:38:16'},
#  {'id': 7001018,
#   'name': "Lion's Lair Trail",
#   'type': 'Trail',
#   'summary': 'Fantastic views from a smooth, well-built trail.',
#   'difficulty': 'greenBlue',
#   'stars': 4.6,
#   'starVotes': 17,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7001018/lions-lair-trail',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7039883_sqsmall_1555092747.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7039883_small_1555092747.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7039883_smallMed_1555092747.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7039883_medium_1555092747.jpg',
#   'length': 2.2,
#   'ascent': 711,
#   'descent': -40,
#   'high': 6807,
#   'low': 6113,
#   'longitude': -105.3159,
#   'latitude': 40.0336,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7003737,
#   'name': 'Eldorado Canyon Trail',
#   'type': 'Trail',
#   'summary': 'A scenic and fairly easy climb ending at South Boulder Creek and Walker Ranch.',
#   'difficulty': 'blue',
#   'stars': 3.8,
#   'starVotes': 37,
#   'location': 'Coal Creek, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7003737/eldorado-canyon-trail',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7024620_sqsmall_1554847328.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7024620_small_1554847328.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7024620_smallMed_1554847328.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7024620_medium_1554847328.jpg',
#   'length': 3.1,
#   'ascent': 1057,
#   'descent': -735,
#   'high': 7087,
#   'low': 6128,
#   'longitude': -105.2944,
#   'latitude': 39.9309,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-08-05 20:50:22'},
#  {'id': 7004594,
#   'name': 'Green Mountain West Ridge',
#   'type': 'Trail',
#   'summary': 'The easiest route to the spectacular summit of Green Mountain.',
#   'difficulty': 'blue',
#   'stars': 4,
#   'starVotes': 29,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7004594/green-mountain-west-ridge',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7003740_sqsmall_1554235436.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7003740_small_1554235436.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003740_smallMed_1554235436.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7003740_medium_1554235436.jpg',
#   'length': 1.4,
#   'ascent': 491,
#   'descent': -89,
#   'high': 8095,
#   'low': 7621,
#   'longitude': -105.3234,
#   'latitude': 39.9833,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry',
#   'conditionDate': '2019-07-17 15:26:39'},
#  {'id': 7018006,
#   'name': 'Mule Deer Trail',
#   'type': 'Trail',
#   'summary': 'A singletrack loop through a variety of pine forests and mountain terrain with scenic views.',
#   'difficulty': 'blue',
#   'stars': 4.3,
#   'starVotes': 18,
#   'location': 'Central City, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7018006/mule-deer-trail',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7051822_sqsmall_1555693701.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7051822_small_1555693701.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7051822_smallMed_1555693701.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7051822_medium_1555693701.jpg',
#   'length': 9.1,
#   'ascent': 1211,
#   'descent': -1203,
#   'high': 9493,
#   'low': 8554,
#   'longitude': -105.4451,
#   'latitude': 39.8498,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry',
#   'conditionDate': '2019-06-10 11:10:02'},
#  {'id': 7031846,
#   'name': 'Ceran Saint Vrain Trail',
#   'type': 'Trail',
#   'summary': 'This is an easy trail that follows pleasant forest along South Saint Vrain Creek.',
#   'difficulty': 'greenBlue',
#   'stars': 4.6,
#   'starVotes': 12,
#   'location': 'Nederland, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7031846/ceran-saint-vrain-trail',
#   'imgSqSmall': '',
#   'imgSmall': '',
#   'imgSmallMed': '',
#   'imgMedium': '',
#   'length': 1.9,
#   'ascent': 96,
#   'descent': -374,
#   'high': 8332,
#   'low': 8037,
#   'longitude': -105.4422,
#   'latitude': 40.1245,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Mostly Dry, Some Mud - Some mud but fine in normal shoes and for camping.',
#   'conditionDate': '2019-06-01 16:27:36'},
#  {'id': 138,
#   'name': 'Mount Sanitas Trail',
#   'type': 'Trail',
#   'summary': 'Mega-popular Boulder classic that is sure to get your blood pumping',
#   'difficulty': 'blueBlack',
#   'stars': 4.3,
#   'starVotes': 17,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/138/mount-sanitas-trail',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7039883_sqsmall_1555092747.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7039883_small_1555092747.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7039883_smallMed_1555092747.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7039883_medium_1555092747.jpg',
#   'length': 1.3,
#   'ascent': 1282,
#   'descent': -3,
#   'high': 6792,
#   'low': 5513,
#   'longitude': -105.2963,
#   'latitude': 40.0206,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry',
#   'conditionDate': '2019-07-17 21:36:02'},
#  {'id': 7007036,
#   'name': 'Forsythe Canyon Trail',
#   'type': 'Trail',
#   'summary': 'A Boulder mountain trail, more remote than the bustle of Chautauqua Trail or Sanitas Valley Trail.',
#   'difficulty': 'greenBlue',
#   'stars': 4.2,
#   'starVotes': 17,
#   'location': 'Coal Creek, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7007036/forsythe-canyon-trail',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7033209_sqsmall_1554997480.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7033209_small_1554997480.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7033209_smallMed_1554997480.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7033209_medium_1554997480.jpg',
#   'length': 1.2,
#   'ascent': 1,
#   'descent': -412,
#   'high': 7670,
#   'low': 7259,
#   'longitude': -105.3958,
#   'latitude': 39.9609,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7002938,
#   'name': 'Boy Scout',
#   'type': 'Trail',
#   'summary': "Access some excellent views of the Indian Peaks at May's Point from this trail.",
#   'difficulty': 'blue',
#   'stars': 5,
#   'starVotes': 2,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7002938/boy-scout',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7003658_sqsmall_1554234777.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7003658_small_1554234777.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003658_smallMed_1554234777.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7003658_medium_1554234777.jpg',
#   'length': 0.7,
#   'ascent': 139,
#   'descent': -124,
#   'high': 6865,
#   'low': 6765,
#   'longitude': -105.3032,
#   'latitude': 40.0041,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7000331,
#   'name': 'Royal Arch Trail',
#   'type': 'Trail',
#   'summary': 'A technical trail that rewards with great views and a natural arch.',
#   'difficulty': 'blueBlack',
#   'stars': 4.4,
#   'starVotes': 13,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7000331/royal-arch-trail',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7024878_sqsmall_1554847839.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7024878_small_1554847839.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7024878_smallMed_1554847839.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7024878_medium_1554847839.jpg',
#   'length': 0.9,
#   'ascent': 905,
#   'descent': -105,
#   'high': 6896,
#   'low': 6096,
#   'longitude': -105.2875,
#   'latitude': 39.991,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry',
#   'conditionDate': '2019-08-15 19:15:48'},
#  {'id': 7001532,
#   'name': 'Shadow Canyon',
#   'type': 'Trail',
#   'summary': 'A stiff climb to the sandy saddle between Bear Peak and South Boulder Peak.',
#   'difficulty': 'black',
#   'stars': 4.3,
#   'starVotes': 12,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7001532/shadow-canyon',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7029226_sqsmall_1554920205.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7029226_small_1554920205.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7029226_smallMed_1554920205.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7029226_medium_1554920205.jpg',
#   'length': 1.1,
#   'ascent': 1608,
#   'descent': 0,
#   'high': 8178,
#   'low': 6570,
#   'longitude': -105.2869,
#   'latitude': 39.9457,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7000072,
#   'name': 'Fern Canyon Trail',
#   'type': 'Trail',
#   'summary': 'A steep, technical ascent to Bear Peak from the Mesa Trail.',
#   'difficulty': 'black',
#   'stars': 4.2,
#   'starVotes': 13,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7000072/fern-canyon-trail',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7061992_sqsmall_1566068327.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7061992_small_1566068327.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7061992_smallMed_1566068327.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7061992_medium_1566068327.jpg',
#   'length': 1.4,
#   'ascent': 2031,
#   'descent': 0,
#   'high': 8413,
#   'low': 6382,
#   'longitude': -105.2834,
#   'latitude': 39.9696,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-08-10 16:38:16'},
#  {'id': 7006025,
#   'name': 'Woods Quarry',
#   'type': 'Trail',
#   'summary': 'Cool stone chairs and an awesome view reward those who climb this short, steep Mesa Trail detour.',
#   'difficulty': 'blue',
#   'stars': 4.3,
#   'starVotes': 11,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7006025/woods-quarry',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7005529_sqsmall_1554312322.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7005529_small_1554312322.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7005529_smallMed_1554312322.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7005529_medium_1554312322.jpg',
#   'length': 0.4,
#   'ascent': 105,
#   'descent': -169,
#   'high': 6359,
#   'low': 6190,
#   'longitude': -105.2859,
#   'latitude': 39.9856,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7004928,
#   'name': 'Mallory Cave Trail',
#   'type': 'Trail',
#   'summary': 'A steep trail to nice cave (cave currently closed).',
#   'difficulty': 'blue',
#   'stars': 4.3,
#   'starVotes': 11,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7004928/mallory-cave-trail',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7005332_sqsmall_1554311942.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7005332_small_1554311942.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7005332_smallMed_1554311942.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7005332_medium_1554311942.jpg',
#   'length': 0.8,
#   'ascent': 866,
#   'descent': -10,
#   'high': 7076,
#   'low': 6210,
#   'longitude': -105.2842,
#   'latitude': 39.978,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry - Cave closed to protect the bats',
#   'conditionDate': '2019-07-16 23:10:53'},
#  {'id': 7010440,
#   'name': 'Burro Trail',
#   'type': 'Trail',
#   'summary': "A nice scenic loop that packs in more climbing than you'd expect.",
#   'difficulty': 'blue',
#   'stars': 3.9,
#   'starVotes': 17,
#   'location': 'Coal Creek, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7010440/burro-trail',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7022842_sqsmall_1554844079.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7022842_small_1554844079.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7022842_smallMed_1554844079.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7022842_medium_1554844079.jpg',
#   'length': 4.1,
#   'ascent': 1034,
#   'descent': -918,
#   'high': 8651,
#   'low': 7826,
#   'longitude': -105.3785,
#   'latitude': 39.8464,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Mostly Dry',
#   'conditionDate': '2019-06-23 13:47:35'},
#  {'id': 7001071,
#   'name': 'Canyon Loop',
#   'type': 'Trail',
#   'summary': 'A quick loop with easy access. Offers great views and forested sections.',
#   'difficulty': 'blue',
#   'stars': 4.1,
#   'starVotes': 13,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7001071/canyon-loop',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7007794_sqsmall_1554323598.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7007794_small_1554323598.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7007794_smallMed_1554323598.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7007794_medium_1554323598.jpg',
#   'length': 3.2,
#   'ascent': 490,
#   'descent': -491,
#   'high': 6589,
#   'low': 6176,
#   'longitude': -105.3446,
#   'latitude': 40.0164,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7010672,
#   'name': 'Green Bear',
#   'type': 'Trail',
#   'summary': 'A beautiful trail that provides access to Green Mountain from South Boulder trailheads.',
#   'difficulty': 'blue',
#   'stars': 4.5,
#   'starVotes': 4,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7010672/green-bear',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7032444_sqsmall_1554933226.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7032444_small_1554933226.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7032444_smallMed_1554933226.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7032444_medium_1554933226.jpg',
#   'length': 1.4,
#   'ascent': 31,
#   'descent': -468,
#   'high': 7659,
#   'low': 7222,
#   'longitude': -105.3087,
#   'latitude': 39.9826,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7000134,
#   'name': 'South Boulder Peak',
#   'type': 'Trail',
#   'summary': 'A ridgetop trail connecting two Front Range peaks.',
#   'difficulty': 'blueBlack',
#   'stars': 4.4,
#   'starVotes': 5,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7000134/south-boulder-peak',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7038791_sqsmall_1555089655.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7038791_small_1555089655.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7038791_smallMed_1555089655.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7038791_medium_1555089655.jpg',
#   'length': 0.3,
#   'ascent': 337,
#   'descent': 0,
#   'high': 8534,
#   'low': 8197,
#   'longitude': -105.2971,
#   'latitude': 39.9567,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-08-26 19:02:18'},
#  {'id': 7000067,
#   'name': 'Skunk Canyon Trail',
#   'type': 'Trail',
#   'summary': 'A switchbacking trail that leads from the bottom of Skunk Canyon to the Mesa Trail.',
#   'difficulty': 'blue',
#   'stars': 4.3,
#   'starVotes': 7,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7000067/skunk-canyon-trail',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7000216_sqsmall_1554159047.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7000216_small_1554159047.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7000216_smallMed_1554159047.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7000216_medium_1554159047.jpg',
#   'length': 1.4,
#   'ascent': 548,
#   'descent': -2,
#   'high': 6262,
#   'low': 5715,
#   'longitude': -105.2736,
#   'latitude': 39.9894,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Some Mud',
#   'conditionDate': '2019-06-22 21:14:02'},
#  {'id': 7004043,
#   'name': 'Wapiti Trail',
#   'type': 'Trail',
#   'summary': 'The main trail at Heil climbing up from the trailhead to the Ponderosa loop and beyond.',
#   'difficulty': 'greenBlue',
#   'stars': 4.3,
#   'starVotes': 7,
#   'location': 'Lyons, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7004043/wapiti-trail',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7007795_sqsmall_1554323599.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7007795_small_1554323599.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7007795_smallMed_1554323599.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7007795_medium_1554323599.jpg',
#   'length': 2.7,
#   'ascent': 813,
#   'descent': 0,
#   'high': 6712,
#   'low': 5898,
#   'longitude': -105.3002,
#   'latitude': 40.1494,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': 'Dry',
# ...
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7003963_small_1554236063.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7003963_smallMed_1554236063.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7003963_medium_1554236063.jpg',
#   'length': 0,
#   'ascent': 5,
#   'descent': -5,
#   'high': 5627,
#   'low': 5622,
#   'longitude': -105.26,
#   'latitude': 39.9396,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7013519,
#   'name': 'Sanitas Valley Spur',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'green',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7013519/sanitas-valley-spur',
#   'imgSqSmall': '',
#   'imgSmall': '',
#   'imgSmallMed': '',
#   'imgMedium': '',
#   'length': 0.1,
#   'ascent': 0,
#   'descent': -28,
#   'high': 5563,
#   'low': 5535,
#   'longitude': -105.2957,
#   'latitude': 40.0217,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7006022,
#   'name': 'McClintock Access',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'green',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7006022/mcclintock-access',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7030523_sqsmall_1554927152.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7030523_small_1554927152.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7030523_smallMed_1554927152.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7030523_medium_1554927152.jpg',
#   'length': 0.1,
#   'ascent': 0,
#   'descent': -13,
#   'high': 5731,
#   'low': 5717,
#   'longitude': -105.2802,
#   'latitude': 39.9972,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 343,
#   'name': 'Dakota Ridge Lower Cutoff',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'greenBlue',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/343/dakota-ridge-lower-cutoff',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7000178_sqsmall_1554158948.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7000178_small_1554158948.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7000178_smallMed_1554158948.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7000178_medium_1554158948.jpg',
#   'length': 0.1,
#   'ascent': 13,
#   'descent': -13,
#   'high': 5677,
#   'low': 5664,
#   'longitude': -105.2961,
#   'latitude': 40.025,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7000112,
#   'name': 'NCAR Connector',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'green',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7000112/ncar-connector',
#   'imgSqSmall': '',
#   'imgSmall': '',
#   'imgSmallMed': '',
#   'imgMedium': '',
#   'length': 0.1,
#   'ascent': 0,
#   'descent': -29,
#   'high': 6189,
#   'low': 6160,
#   'longitude': -105.278,
#   'latitude': 39.9774,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7005378,
#   'name': 'Neighborhood access',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'green',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7005378/neighborhood-access',
#   'imgSqSmall': '',
#   'imgSmall': '',
#   'imgSmallMed': '',
#   'imgMedium': '',
#   'length': 0,
#   'ascent': 0,
#   'descent': -3,
#   'high': 5563,
#   'low': 5560,
#   'longitude': -105.2886,
#   'latitude': 40.0477,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-07-23 14:25:24'},
#  {'id': 7005372,
#   'name': 'Neighborhood access',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'green',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7005372/neighborhood-access',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7004716_sqsmall_1554310635.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7004716_small_1554310635.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7004716_smallMed_1554310635.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7004716_medium_1554310635.jpg',
#   'length': 0,
#   'ascent': 0,
#   'descent': -14,
#   'high': 5560,
#   'low': 5546,
#   'longitude': -105.2869,
#   'latitude': 40.0481,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-07-23 14:25:24'},
#  {'id': 7018796,
#   'name': 'Lime Kiln Spur',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'green',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Lyons, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7018796/lime-kiln-spur',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7018512_sqsmall_1554830961.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7018512_small_1554830961.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7018512_smallMed_1554830961.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7018512_medium_1554830961.jpg',
#   'length': 0,
#   'ascent': 0,
#   'descent': -5,
#   'high': 5966,
#   'low': 5961,
#   'longitude': -105.2987,
#   'latitude': 40.1512,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7004517,
#   'name': 'Ranch Overlook',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'green',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7004517/ranch-overlook',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7004156_sqsmall_1554244157.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7004156_small_1554244157.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7004156_smallMed_1554244157.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7004156_medium_1554244157.jpg',
#   'length': 0.1,
#   'ascent': 0,
#   'descent': -2,
#   'high': 5534,
#   'low': 5531,
#   'longitude': -105.2683,
#   'latitude': 40.0766,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-07-23 14:25:24'},
#  {'id': 7004876,
#   'name': 'Neighborhood Access',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'green',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7004876/neighborhood-access',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7004698_sqsmall_1554310591.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7004698_small_1554310591.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7004698_smallMed_1554310591.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7004698_medium_1554310591.jpg',
#   'length': 0,
#   'ascent': 0,
#   'descent': -1,
#   'high': 5674,
#   'low': 5674,
#   'longitude': -105.2911,
#   'latitude': 40.0656,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-07-23 14:25:24'},
#  {'id': 7004801,
#   'name': 'Neighborhood Access',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'greenBlue',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Broomfield, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7004801/neighborhood-access',
#   'imgSqSmall': '',
#   'imgSmall': '',
#   'imgSmallMed': '',
#   'imgMedium': '',
#   'length': 0.1,
#   'ascent': 0,
#   'descent': -46,
#   'high': 5453,
#   'low': 5407,
#   'longitude': -105.0858,
#   'latitude': 39.9397,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7018613,
#   'name': 'Viele Lake Connector',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'green',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7018613/viele-lake-connector',
#   'imgSqSmall': '',
#   'imgSmall': '',
#   'imgSmallMed': '',
#   'imgMedium': '',
#   'length': 0.1,
#   'ascent': 6,
#   'descent': 0,
#   'high': 5495,
#   'low': 5488,
#   'longitude': -105.2489,
#   'latitude': 39.9754,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7018567,
#   'name': 'Viele Lake to Fairview Connector',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'green',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7018567/viele-lake-to-fairview-connector',
#   'imgSqSmall': '',
#   'imgSmall': '',
#   'imgSmallMed': '',
#   'imgMedium': '',
#   'length': 0.4,
#   'ascent': 10,
#   'descent': -7,
#   'high': 5517,
#   'low': 5508,
#   'longitude': -105.2479,
#   'latitude': 39.9731,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7035062,
#   'name': 'Geer Canyon Connector',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'greenBlue',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Lyons, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7035062/geer-canyon-connector',
#   'imgSqSmall': '',
#   'imgSmall': '',
#   'imgSmallMed': '',
#   'imgMedium': '',
#   'length': 0.1,
#   'ascent': 1,
#   'descent': -5,
#   'high': 5897,
#   'low': 5893,
#   'longitude': -105.2995,
#   'latitude': 40.1456,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7005505,
#   'name': 'Wonderland Hills Paved Path',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'green',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7005505/wonderland-hills-paved-path',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7004886_sqsmall_1554311001.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7004886_small_1554311001.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7004886_smallMed_1554311001.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7004886_medium_1554311001.jpg',
#   'length': 0.2,
#   'ascent': 0,
#   'descent': -26,
#   'high': 5640,
#   'low': 5614,
#   'longitude': -105.2921,
#   'latitude': 40.0434,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-07-23 14:25:24'},
#  {'id': 7005503,
#   'name': 'Wonderland Hills Paved Path',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'green',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7005503/wonderland-hills-paved-path',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7004886_sqsmall_1554311001.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7004886_small_1554311001.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7004886_smallMed_1554311001.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7004886_medium_1554311001.jpg',
#   'length': 0.5,
#   'ascent': 19,
#   'descent': -49,
#   'high': 5616,
#   'low': 5567,
#   'longitude': -105.2855,
#   'latitude': 40.0437,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-07-23 14:25:24'},
#  {'id': 7005379,
#   'name': 'Neighborhood Access',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'green',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7005379/neighborhood-access',
#   'imgSqSmall': '',
#   'imgSmall': '',
#   'imgSmallMed': '',
#   'imgMedium': '',
#   'length': 0,
#   'ascent': 8,
#   'descent': 0,
#   'high': 5636,
#   'low': 5627,
#   'longitude': -105.2917,
#   'latitude': 40.0531,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-07-23 14:25:24'},
#  {'id': 7004802,
#   'name': 'Neighborhood Access',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'green',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Broomfield, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7004802/neighborhood-access',
#   'imgSqSmall': '',
#   'imgSmall': '',
#   'imgSmallMed': '',
#   'imgMedium': '',
#   'length': 0.3,
#   'ascent': 0,
#   'descent': -54,
#   'high': 5449,
#   'low': 5395,
#   'longitude': -105.0737,
#   'latitude': 39.9448,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7004800,
#   'name': 'Neighborhood Access',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'green',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Broomfield, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7004800/neighborhood-access',
#   'imgSqSmall': '',
#   'imgSmall': '',
#   'imgSmallMed': '',
#   'imgMedium': '',
#   'length': 0.1,
#   'ascent': 0,
#   'descent': -15,
#   'high': 5422,
#   'low': 5407,
#   'longitude': -105.0839,
#   'latitude': 39.9377,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7005377,
#   'name': 'Foothills Spur',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'green',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7005377/foothills-spur',
#   'imgSqSmall': '',
#   'imgSmall': '',
#   'imgSmallMed': '',
#   'imgMedium': '',
#   'length': 0.1,
#   'ascent': 7,
#   'descent': 0,
#   'high': 5623,
#   'low': 5616,
#   'longitude': -105.2881,
#   'latitude': 40.062,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-07-23 14:25:24'},
#  {'id': 7004799,
#   'name': 'Neighborhood access',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'greenBlue',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Broomfield, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7004799/neighborhood-access',
#   'imgSqSmall': '',
#   'imgSmall': '',
#   'imgSmallMed': '',
#   'imgMedium': '',
#   'length': 0.1,
#   'ascent': 0,
#   'descent': -38,
#   'high': 5463,
#   'low': 5425,
#   'longitude': -105.0979,
#   'latitude': 39.9345,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7010709,
#   'name': 'Dots Connector',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'green',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Nederland, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7010709/dots-connector',
#   'imgSqSmall': '',
#   'imgSmall': '',
#   'imgSmallMed': '',
#   'imgMedium': '',
#   'length': 0.1,
#   'ascent': 6,
#   'descent': -11,
#   'high': 8657,
#   'low': 8647,
#   'longitude': -105.4494,
#   'latitude': 39.9683,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'},
#  {'id': 7005523,
#   'name': 'Broadway to Wonderland Lake Access',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'green',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Boulder, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7005523/broadway-to-wonderland-lake-access',
#   'imgSqSmall': 'https://cdn-files.apstatic.com/hike/7004902_sqsmall_1554311039.jpg',
#   'imgSmall': 'https://cdn-files.apstatic.com/hike/7004902_small_1554311039.jpg',
#   'imgSmallMed': 'https://cdn-files.apstatic.com/hike/7004902_smallMed_1554311039.jpg',
#   'imgMedium': 'https://cdn-files.apstatic.com/hike/7004902_medium_1554311039.jpg',
#   'length': 0.2,
#   'ascent': 33,
#   'descent': 0,
#   'high': 5593,
#   'low': 5559,
#   'longitude': -105.2822,
#   'latitude': 40.0437,
#   'conditionStatus': 'All Clear',
#   'conditionDetails': '',
#   'conditionDate': '2019-07-23 14:25:24'},
#  {'id': 7053888,
#   'name': 'Dots Access - Blue Dot Connector',
#   'type': 'Connector',
#   'summary': '',
#   'difficulty': 'green',
#   'stars': 0,
#   'starVotes': 0,
#   'location': 'Nederland, Colorado',
#   'url': 'https://www.hikingproject.com/trail/7053888/dots-access-blue-dot-connector',
#   'imgSqSmall': '',
#   'imgSmall': '',
#   'imgSmallMed': '',
#   'imgMedium': '',
#   'length': 0.1,
#   'ascent': 0,
#   'descent': -23,
#   'high': 8673,
#   'low': 8650,
#   'longitude': -105.4528,
#   'latitude': 39.9659,
#   'conditionStatus': 'Unknown',
#   'conditionDetails': None,
#   'conditionDate': '1970-01-01 00:00:00'}]

# %% [markdown]
# 5. Loop through results to load a pandas dataframe, and check this has completed successfully:

# %%
df = pd.DataFrame(columns=['name', 'type', 'difficulty', 'stars', 'starVotes', 
                           'location', 'length', 'ascent', 'descent', 
                           'high', 'low', 'latitude', 'longitude'])

for v in results:
    # initialize list of lists 
    data = [v['name'], 
            v['type'], 
            v['difficulty'],
            v['stars'],
            v['starVotes'],
            v['location'],
            v['length'], 
            v['ascent'], 
            v['descent'], 
            v['high'],
            v['low'],
            v['latitude'],
            v['longitude']] 
    # Create the pandas DataFrame 
    df_temp = pd.DataFrame([data], columns=['name', 'type', 'difficulty', 'stars', 'starVotes', 'location', 'length', 'ascent', 'descent', 'high', 'low', 'latitude', 'longitude']) 
    # append temp dataframe to main dataframe 
    df = df.append(df_temp).reset_index(drop=True)
    
df
# Out:
#                                                   name           type  \
# 0                               Bear Peak Out and Back  Featured Hike
# 1                            Sunshine Lion's Lair Loop  Featured Hike
# 2                             Boulder Skyline Traverse  Featured Hike
# 3                              Royal Arch Out and Back  Featured Hike
# 4                                         Walker Ranch  Featured Hike
# 5           Green Mountain via Ranger/Saddle Rock Loop  Featured Hike
# 6                                   Mount Sanitas Loop  Featured Hike
# 7                                     Betasso Preserve  Featured Hike
# 8                                  Mountain Lion Trail  Featured Hike
# 9                   Golden Gate Canyon State Park Loop  Featured Hike
# 10                  Marshall Mesa to Spring Brook Loop  Featured Hike
# 11                               Welcome to Chautauqua  Featured Hike
# 12                                  Sugarloaf Mountain  Featured Hike
# 13                               Flagstaff Summit Loop  Featured Hike
# 14                                       East Mag Tour  Featured Hike
# 15                         Indian Peaks Traverse (IPT)  Featured Hike
# 16                                       Dirty Bismark  Featured Hike
# 17                                     South Mesa Loop  Featured Hike
# 18                           Boulder Valley Ranch Loop  Featured Hike
# 19                           Heil - Picture Rock Combo  Featured Hike
# 20                                      Shanahan Ridge  Featured Hike
# 21                                  Hogback Ridge Loop  Featured Hike
# 22                 Dakota Ridge to Sanitas Valley Loop  Featured Hike
# 23                                 Mesa Reservoir Loop  Featured Hike
# 24                    Green-Bear Combo from Chautauqua  Featured Hike
# 25                           Marshall Mesa Valley Loop  Featured Hike
# 26               Fourmile Creek - Gold Hill Connection  Featured Hike
# 27                  Spring Brook / Goshawk Double Loop  Featured Hike
# 28                              Teller Farm - The Tank  Featured Hike
# 29   Coyote Run - Harper Lake - Davidson Mesa - Lou...  Featured Hike
# ..                                                 ...            ...
# 333                                 Halfway House Spur      Connector
# 334                 Broadway to Wonderland Lake Access      Connector
# 335                                     NCAR Connector      Connector
# 336                        Wonderland Hills Paved Path      Connector
# 337                                Neighborhood Access      Connector
# 338                                Neighborhood Access      Connector
# 339                                     Homestead Spur      Connector
# 340                                Sanitas Valley Spur      Connector
# 341                                  McClintock Access      Connector
# 342                          Dakota Ridge Lower Cutoff      Connector
# 343                                     NCAR Connector      Connector
# 344                                Neighborhood access      Connector
# 345                                Neighborhood access      Connector
# 346                                     Lime Kiln Spur      Connector
# 347                                     Ranch Overlook      Connector
# 348                                Neighborhood Access      Connector
# 349                                Neighborhood Access      Connector
# 350                               Viele Lake Connector      Connector
# 351                   Viele Lake to Fairview Connector      Connector
# 352                              Geer Canyon Connector      Connector
# 353                        Wonderland Hills Paved Path      Connector
# 354                        Wonderland Hills Paved Path      Connector
# 355                                Neighborhood Access      Connector
# 356                                Neighborhood Access      Connector
# 357                                Neighborhood Access      Connector
# 358                                     Foothills Spur      Connector
# 359                                Neighborhood access      Connector
# 360                                     Dots Connector      Connector
# 361                 Broadway to Wonderland Lake Access      Connector
# 362                   Dots Access - Blue Dot Connector      Connector
#
#     difficulty  stars starVotes              location  length ascent descent  \
# 0    blueBlack    4.6       108     Boulder, Colorado     5.7   2541   -2540
# 1         blue    4.5       103     Boulder, Colorado     5.3   1261   -1282
# 2        black    4.7        70    Superior, Colorado    16.3   5409   -5492
# 3    blueBlack    4.4       145     Boulder, Colorado     3.3   1311   -1312
# 4    blueBlack    4.5       118  Coal Creek, Colorado     7.6   1594   -1585
# 5    blueBlack    4.5        76     Boulder, Colorado     4.9   2305   -2277
# 6    blueBlack    4.1       102     Boulder, Colorado     3.2   1281   -1280
# 7         blue    4.2        58     Boulder, Colorado     6.7    776    -778
# 8         blue    4.5        50  Coal Creek, Colorado     6.9   1531   -1509
# 9    blueBlack    4.4        24  Coal Creek, Colorado    13.2   2232   -2230
# 10        blue    4.4        25    Superior, Colorado    11.1    893    -893
# 11   greenBlue    4.3        20     Boulder, Colorado     1.3    436    -434
# 12   greenBlue    4.3        18     Boulder, Colorado     1.4    432    -432
# 13   greenBlue    4.3        16     Boulder, Colorado     2.4    346    -337
# 14        blue    3.8        20   Nederland, Colorado     7.5   1005   -1014
# 15   blueBlack    4.5         2     Boulder, Colorado    71.2   9173   -5813
# 16   greenBlue    3.9        15    Superior, Colorado    15.7    970    -970
# 17   greenBlue    3.9        14    Superior, Colorado     3.1    508    -507
# 18       green    4.1         7     Boulder, Colorado     2.9    170    -166
# 19        blue    4.1         7       Lyons, Colorado    20.0   2241   -2241
# 20        blue    3.5        16     Boulder, Colorado     3.9    831    -831
# 21   greenBlue    3.4        19     Boulder, Colorado     2.1    740    -739
# 22   greenBlue    4.0         6     Boulder, Colorado     2.3    458    -458
# 23       green    4.0         3     Boulder, Colorado     1.9     77     -79
# 24       black    4.0         1     Boulder, Colorado    13.5   4512   -4512
# 25   greenBlue    4.0         1    Superior, Colorado     2.8    187    -186
# 26   greenBlue    3.8         4   Nederland, Colorado     4.9    781    -782
# 27        blue    3.5         2    Superior, Colorado     8.3   1065   -1065
# 28       green    3.0         4   Gunbarrel, Colorado    11.0    517    -517
# 29       green    2.8         4  Louisville, Colorado     8.3    334    -330
# ..         ...    ...       ...                   ...     ...    ...     ...
# 333      green    0.0         0     Boulder, Colorado     0.1     25       0
# 334      green    0.0         0     Boulder, Colorado     0.2     25     -15
# 335      green    0.0         0     Boulder, Colorado     0.1     20     -50
# 336      green    0.0         0     Boulder, Colorado     0.2     45       0
# 337      green    0.0         0     Boulder, Colorado     0.1     47       0
# 338      green    0.0         0     Boulder, Colorado     0.0      7       0
# 339      green    0.0         0    Superior, Colorado     0.0      5      -5
# 340      green    0.0         0     Boulder, Colorado     0.1      0     -28
# 341      green    0.0         0     Boulder, Colorado     0.1      0     -13
# 342  greenBlue    0.0         0     Boulder, Colorado     0.1     13     -13
# 343      green    0.0         0     Boulder, Colorado     0.1      0     -29
# 344      green    0.0         0     Boulder, Colorado     0.0      0      -3
# 345      green    0.0         0     Boulder, Colorado     0.0      0     -14
# 346      green    0.0         0       Lyons, Colorado     0.0      0      -5
# 347      green    0.0         0     Boulder, Colorado     0.1      0      -2
# 348      green    0.0         0     Boulder, Colorado     0.0      0      -1
# 349  greenBlue    0.0         0  Broomfield, Colorado     0.1      0     -46
# 350      green    0.0         0     Boulder, Colorado     0.1      6       0
# 351      green    0.0         0     Boulder, Colorado     0.4     10      -7
# 352  greenBlue    0.0         0       Lyons, Colorado     0.1      1      -5
# 353      green    0.0         0     Boulder, Colorado     0.2      0     -26
# 354      green    0.0         0     Boulder, Colorado     0.5     19     -49
# 355      green    0.0         0     Boulder, Colorado     0.0      8       0
# 356      green    0.0         0  Broomfield, Colorado     0.3      0     -54
# 357      green    0.0         0  Broomfield, Colorado     0.1      0     -15
# 358      green    0.0         0     Boulder, Colorado     0.1      7       0
# 359  greenBlue    0.0         0  Broomfield, Colorado     0.1      0     -38
# 360      green    0.0         0   Nederland, Colorado     0.1      6     -11
# 361      green    0.0         0     Boulder, Colorado     0.2     33       0
# 362      green    0.0         0   Nederland, Colorado     0.1      0     -23
#
#       high   low  latitude  longitude
# 0     8342  6103   39.9787  -105.2755
# 1     6800  5530   40.0200  -105.2979
# 2     8492  5417   39.9388  -105.2582
# 3     6917  5691   39.9997  -105.2830
# 4     7335  6439   39.9511  -105.3378
# 5     8099  5806   39.9975  -105.2928
# 6     6780  5521   40.0202  -105.2977
# 7     6575  6178   40.0164  -105.3446
# 8     8901  7627   39.8505  -105.3606
# 9     9493  8228   39.8330  -105.4084
# 10    6236  5567   39.9527  -105.2313
# 11    6139  5703   39.9988  -105.2829
# 12    8892  8460   40.0255  -105.4251
# 13    6919  6758   40.0041  -105.3032
# 14    8704  8384   39.9535  -105.4752
# 15   11665  5425   40.0137  -105.2946
# 16    5960  5522   39.9527  -105.2310
# 17    6123  5623   39.9388  -105.2582
# 18    5348  5208   40.0800  -105.2627
# 19    6798  5406   40.1494  -105.3002
# 20    6504  5672   39.9746  -105.2668
# 21    6400  5660   40.0688  -105.2898
# 22    5961  5503   40.0207  -105.2942
# 23    5561  5487   40.0764  -105.2775
# 24    8410  5688   39.9997  -105.2830
# 25    5716  5532   39.9528  -105.2313
# 26    9126  8715   40.0412  -105.5234
# 27    6547  5662   39.9381  -105.2566
# 28    5381  5070   40.0218  -105.1586
# 29    5670  5428   39.9819  -105.1468
# ..     ...   ...       ...        ...
# 333   6055  6030   40.0061  -105.2940
# 334   5513  5495   40.0506  -105.2823
# 335   6203  6153   39.9776  -105.2778
# 336   5635  5589   40.0464  -105.2869
# 337   5709  5662   40.0687  -105.2899
# 338   5648  5641   40.0654  -105.2885
# 339   5627  5622   39.9396  -105.2600
# 340   5563  5535   40.0217  -105.2957
# 341   5731  5717   39.9972  -105.2802
# 342   5677  5664   40.0250  -105.2961
# 343   6189  6160   39.9774  -105.2780
# 344   5563  5560   40.0477  -105.2886
# 345   5560  5546   40.0481  -105.2869
# 346   5966  5961   40.1512  -105.2987
# 347   5534  5531   40.0766  -105.2683
# 348   5674  5674   40.0656  -105.2911
# 349   5453  5407   39.9397  -105.0858
# 350   5495  5488   39.9754  -105.2489
# 351   5517  5508   39.9731  -105.2479
# 352   5897  5893   40.1456  -105.2995
# 353   5640  5614   40.0434  -105.2921
# 354   5616  5567   40.0437  -105.2855
# 355   5636  5627   40.0531  -105.2917
# 356   5449  5395   39.9448  -105.0737
# 357   5422  5407   39.9377  -105.0839
# 358   5623  5616   40.0620  -105.2881
# 359   5463  5425   39.9345  -105.0979
# 360   8657  8647   39.9683  -105.4494
# 361   5593  5559   40.0437  -105.2822
# 362   8673  8650   39.9659  -105.4528
#
# [363 rows x 13 columns]
